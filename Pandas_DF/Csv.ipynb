# %%
import pandas as pd
import numpy as np

list_of_data =[["C1", "Lampung", 3], ["C2", "Jakarta", 6], ["C3", "Bogor", 9 ], ["C4", "Tanggerang", 9 ], ["C5", "Cikarang", 7 ]]
numpy_array = np.array(list_of_data)
df_numpy = pd.DataFrame(numpy_array, columns=["ID", "City", "Value"])
print(df_numpy)
# Out:
#    ID        City Value
# 0  C1     Lampung     3
# 1  C2     Jakarta     6
# 2  C3       Bogor     9
# 3  C4  Tanggerang     9
# 4  C5    Cikarang     7

# %%
df_numpy.to_csv("data.csv", index=False)

# %%
pd.read_csv("data.csv")
# Out:
#    ID        City  Value
# 0  C1     Lampung      3
# 1  C2     Jakarta      6
# 2  C3       Bogor      9
# 3  C4  Tanggerang      9
# 4  C5    Cikarang      7
