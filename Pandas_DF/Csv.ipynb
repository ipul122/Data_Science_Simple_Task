# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "ID": ["C1", "C2", "C3", "C4", "C5","C6","C7","C8","C9","C10"], 
    "City": ["Lampung", "Jakarta", "Bogor", "Tanggerang", "Cikarang", "Bandung", "Surabaya", "Medan", "Semarang", "Yogyakarta"], 
    "Value": [3, 6, 9, 9, 7, 5, 8, 4, 6, 7]  
})
print(df)
# Out:
#     ID        City  Value
# 0   C1     Lampung      3
# 1   C2     Jakarta      6
# 2   C3       Bogor      9
# 3   C4  Tanggerang      9
# 4   C5    Cikarang      7
# 5   C6     Bandung      5
# 6   C7    Surabaya      8
# 7   C8       Medan      4
# 8   C9    Semarang      6
# 9  C10  Yogyakarta      7

# %%
df.to_csv("data.csv", index=False)

# %%
pd.read_csv("data.csv")
# Out:
#     ID        City  Value
# 0   C1     Lampung      3
# 1   C2     Jakarta      6
# 2   C3       Bogor      9
# 3   C4  Tanggerang      9
# 4   C5    Cikarang      7
# 5   C6     Bandung      5
# 6   C7    Surabaya      8
# 7   C8       Medan      4
# 8   C9    Semarang      6
# 9  C10  Yogyakarta      7
